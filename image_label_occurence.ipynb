# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib

# %%
input_path = './result/travel/labels'

# %%
label_counts = {}

# %%
os.listdir(input_path)
# Out:
# ['robbeddington', 'melody__yeon', 'amazing4love', 'matthi.gui', 'sullyn____']

# %%
for user in os.listdir(input_path):
    print(user)
    for filename in os.listdir(os.path.join(input_path, user)):
        if filename.endswith(".txt"):
            file = open(os.path.join(input_path , user, filename), 'r')
            while True:
                label = file.readline()
                if not label:
                    break
                elif label.startswith('Labels:'):
                    continue
                label = label.rstrip()
                if label in label_counts:
                    label_counts[label] += 1
                else:
                    label_counts[label] = 1
# Out:
# robbeddington
# melody__yeon
# amazing4love
# matthi.gui
# sullyn____

# %%
label_counts
# Out:
# {'Food': 49,
#  'Tableware': 51,
#  'Ingredient': 42,
#  'Plate': 44,
#  'Staple food': 3,
#  'Cuisine': 25,
#  'Serveware': 39,
#  'Dish': 8,
#  'Coffee': 4,
#  'Recipe': 15,
#  'Drinkware': 33,
#  'Dishware': 49,
#  'Stemware': 2,
#  'Barware': 2,
#  'Table': 54,
#  'Cup': 30,
#  'Baked goods': 5,
#  'Bottle': 1,
#  'Sliced bread': 1,
#  'Wiener melange': 1,
#  'Espressino': 1,
#  'Single-origin coffee': 1,
#  'Coffee cup': 12,
#  'Caffè macchiato': 1,
#  'Furniture': 22,
#  'Tablecloth': 1,
#  'Plant': 22,
#  'Juice': 1,
#  'Cocktail': 1,
#  'Cake': 2,
#  'Wood': 25,
#  'Saucer': 10,
#  'Deep frying': 1,
#  'Keemun': 1,
#  'Lapsang souchong': 1,
#  'Produce': 1,
#  'Property': 11,
#  'Window': 21,
#  'Building': 36,
#  'Chair': 13,
#  'Interior design': 17,
#  'Urban design': 3,
#  'Flower': 2,
#  'Door': 12,
#  'Outdoor table': 2,
#  'Facade': 16,
#  'Tints and shades': 10,
#  'Bicycle': 1,
#  'Tire': 2,
#  'Wheel': 2,
#  'Bicycle wheel': 1,
#  'Bicycle tire': 1,
# ...

# %%
sorted_labels, sorted_counts = zip(*sorted(label_counts.items(), key=lambda x: x[1], reverse=True)[:20])

# %%
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['font.family'] = 'appleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(20, 10))
plt.bar(sorted_labels, sorted_counts)
plt.xlabel('라벨')
plt.ylabel('횟수')
plt.title('라벨별 빈도 #travel')
plt.xticks(rotation=45, ha="right")
plt.savefig('./result/occurrence_travel.png', bbox_inches='tight')
plt.show()

# %%
from wordcloud import WordCloud

# %%
# Generate word cloud
wordcloud = WordCloud(width=1024, height=720, background_color='white').generate_from_frequencies(label_counts)

# Display the generated image:
plt.figure(figsize=(40, 30))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('./result/wordcloud_travel.png')
plt.show()
